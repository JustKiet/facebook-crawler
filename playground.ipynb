# %%
import json

with open('facebook_posts.json', 'r', encoding='utf-8') as f:
    facebook_posts = json.load(f)

# %%
from facebook_crawler.llm_processing import Post

for post in facebook_posts:
    try:
        post_obj = Post(post)
        print(json.dumps(post_obj.post, ensure_ascii=False, indent=4))
    except Exception:
        continue
# Out:
# {
#     "post_type": "generic",
#     "post_author": "Đơn vị Tác Chiến Điện Tử Comrade Commissar",
#     "content": " || Theo dõi || 0:00 || / || 0:37 || watch || Kiệt || WFy4C8N0oFNzTJsefvIXwcQ4jNNzKZGX0PQ0pYpTm3f3fxtbUYghLcbQg65 || Mấy đứa đòi đi đại hải trình đâu rồi. #ComCom -CT- ",
#     "interactions": {
#         "reactions": "5K || 342 bình luận || 23 lượt chia sẻ || ",
#         "comments": []
#     }
# }
# {
#     "post_type": "generic",
#     "post_author": "Cá Vàng Yugioh Channel",
#     "content": " || Theo dõi || YP01jctwT.com || Tải lên từ di động || #VNC2024 leak Địa điểm thi đấu: Hà Nội. Chắc vẫn ở hội trường NXB Kim Đồng, Quang Trung. Mình có hỏi lại thì BTC bảo khá là chắc kèo. … Xem thêm ",
#     "interactions": {
#         "reactions": "54 || 44 bình luận || 12 lượt chia sẻ || ",
#         "comments": []
#     }
# }
# {
#     "post_type": "generic",
#     "post_author": "P&G Manga Shop",
#     "content": " || Theo dõi || VlsqxZVYX5.com || Tải lên từ di động || Tháng cô hồn đã đủ đầy các loại từ Kinh Đô tới Kido nha Nguồn: Thandangcomics #pgmangashop ",
#     "interactions": {
#         "reactions": "Thành Huế và 20K người khác || 632 bình luận || 502 lượt chia sẻ || ",
#         "comments": []
#     }
# }
# {
#     "post_type": "generic",
#     "post_author": "BEAT 36 THANH HÓA",
#     "content": " || Theo dõi || Hư hình ảnh cờ tổ quốc trên mái || nhà ở Thanh Hóa, lãnh đạo huyện || 0:00 || / || 0:41 || watch || Kiệt || M8duu7P3HZJsSlTheoShrDtDI4K0wVgFmK8P551J6T84oGApORp4NzKo || Rồi, to chuyện ",
#     "interactions": {
#         "reactions": "6K || 1,1K bình luận || 135 lượt chia sẻ || ",
#         "comments": []
#     }
# }
# {
#     "post_type": "generic",
#     "post_author": "Excel Easy",
#     "content": " || excel-easy.com || Learn how to use Excel. 100% free. || Free Excel Course + 300 examples. || Enhance your skills and productivity with our free Excel course! Discover the secrets of this powerful tool at https://excel-easy.com ",
#     "interactions": {
#         "reactions": "253K || 8,6K bình luận || 7K lượt chia sẻ || ",
#         "comments": []
#     }
# }
# {
#     "post_type": "generic",
#     "post_author": "XTV Network",
#     "content": " || Theo dõi || 0:00 || / || 4:18 || watch || KHÓ CHỊU VÔ CÙNG || 341k3Gx0kuVzbZvsn2yGDevsRPILXm02IxZ || KHÓ CHỊU VÔ CÙNG ",
#     "interactions": {
#         "reactions": "9K || 196 bình luận || 25 lượt chia sẻ || ",
#         "comments": []
#     }
# }
# {
#     "post_type": "generic",
#     "post_author": "Hi Peter here",
#     "content": " || Theo dõi || y3Wce47Xs.com || Ảnh trên dòng thời gian || Dưới đây là bình luận của các viên chức Sony khi hãng đang trong quá trình làm TASM2, được hé lộ trong các email bị leak của hãng vào năm 2014:\n\n+ 'Trend đang nổi ở tụi nhỏ bây giờ là mấy cái hoạt động ngoài trời như là chạy bùn, color run và ăn chay đấy. Tụi nhỏ giờ cũng hay ghi N.B.D (No Big Deal) trên mạng xã hội nữa. Tui không biết Người Nhện liệu sẽ có làm những thứ này hay không. Cậu ấy cực kỳ thể thao, khỏe mạnh và dẻo dai. Mấy thứ này là No Big Deal với cậu ta chắc luôn'\n\n+ 'EDM đang là nhạc thịnh hành của giới trẻ bây giờ. Liệu trong phim Người Nhện này sẽ có EDM không? Chuyển động cậu ấy tuyệt đẹp, sẽ rất tuyệt khi lồng yếu tố này với một DJ cực đỉnh'\n\n+ 'Snapchat vừa cho ra mắt chức năng đăng Story, như kiểu đăng khoảnh khắc trong ngày rồi xóa sao 24 tiếng ấy. Nghe khá VIP, kiểu chỉ được mời rồi mới được xem đấy. Nếu được mời vào xem story snapchat của Người Nhện thì sẽ rất cool.'\n\n+ 'Buổi photoshoot của Emma thật tuyệt. Cô ấy cảm thấy rất vui và xinh đẹp. Tụi tôi vừa bàn về việc cô ấy sẽ không xuất hiện trong phần sau và cổ rất muốn thủ vai 'b.itch' một chút. Tụi tôi đã bàn về việc Gwen Stacy trở lại trong hình dáng Carnage như trong comic. Chúng tôi sau đó đã cười khi tưởng tượng ra một Carnage Gwen cực kì sẹc xi. Đáng để cân nhắc trong tương lai. Sẽ khá là nóng bỏng và gay cấn khi thấy cô ấy chiến đấu với Spidey, hoặc chiến đấu với MJ ;)'\n\n#TheAmazingSpiderMan2 #Marvel #Sony || Dưới đây là bình luận của các viên chức Sony khi hãng đang trong quá trình làm TASM2, được hé lộ trong các email bị leak của hãng vào năm 2014: + 'Trend đang nổi ở tụi nhỏ bây giờ là mấy cái hoạt động ngoài trời như là chạy bùn, color run và ăn chay đấy. Tụi nhỏ giờ cũng hay ghi N.B.D (No Big Deal) trên mạng xã hội nữa. Tui không biết Người Nhện liệu sẽ có làm những thứ này hay không. Cậu ấy cực kỳ thể thao, khỏe mạnh và dẻo dai. Mấy thứ này là No Big Deal với cậu ta chắc lu… Xem thêm ",
#     "interactions": {
#         "reactions": "299 || 16 bình luận || 4 lượt chia sẻ || ",
#         "comments": []
#     }
# }

# %%
from facebook_crawler.llm_processing import FacebookPostAnalyst
from facebook_crawler.llm_processing import Post
import json
import os
from Secret.secret import OpenAIKey

os.environ["OPENAI_API_KEY"] = OpenAIKey()

output = []

for post in facebook_posts:
    try:
        post_obj = Post(post)
        
        post_formatted = FacebookPostAnalyst(post_obj)

        output.append(post_formatted)

        print(json.dumps(post_formatted, ensure_ascii=False, indent=4))
    except Exception as e:
        print(e)
        continue
# Out:
# {
#     "postType": "generic",
#     "postGroup": "",
#     "postAuthor": "Đơn vị Tác Chiến Điện Tử Comrade Commissar",
#     "postCaption": "Mấy đứa đòi đi đại hải trình đâu rồi.",
#     "postMediaContent": "Video",
#     "postLikesCount": 5000,
#     "postCommentsCount": 342,
#     "postSharesCount": 23,
#     "postComments": []
# }
# {
#     "postType": "generic",
#     "postGroup": "",
#     "postAuthor": "Cá Vàng Yugioh Channel",
#     "postCaption": "Địa điểm thi đấu: Hà Nội. Chắc vẫn ở hội trường NXB Kim Đồng, Quang Trung. Mình có hỏi lại thì BTC bảo khá là chắc kèo.",
#     "postMediaContent": "None",
#     "postLikesCount": 54,
#     "postCommentsCount": 44,
#     "postSharesCount": 12,
#     "postComments": []
# }
# {
#     "postType": "generic",
#     "postGroup": "",
#     "postAuthor": "P&G Manga Shop",
#     "postCaption": "Tháng cô hồn đã đủ đầy các loại từ Kinh Đô tới Kido nha Nguồn: Thandangcomics #pgmangashop",
#     "postMediaContent": "None",
#     "postLikesCount": 632,
#     "postCommentsCount": 0,
#     "postSharesCount": 502,
#     "postComments": []
# }
# {
#     "postType": "generic",
#     "postGroup": "",
#     "postAuthor": "BEAT 36 THANH HÓA",
#     "postCaption": "Hư hình ảnh cờ tổ quốc trên mái",
#     "postMediaContent": "Video",
#     "postLikesCount": 6000,
#     "postCommentsCount": 1100,
#     "postSharesCount": 135,
#     "postComments": []
# }
# {
#     "postType": "generic",
#     "postGroup": "",
#     "postAuthor": "Excel Easy",
#     "postCaption": "Learn how to use Excel. 100% free.",
#     "postMediaContent": "Yes",
#     "postLikesCount": 253000,
#     "postCommentsCount": 8600,
#     "postSharesCount": 7000,
#     "postComments": []
# }
# {
#     "postType": "generic",
#     "postGroup": "",
#     "postAuthor": "XTV Network",
#     "postCaption": "KHÓ CHỊU VÔ CÙNG",
#     "postMediaContent": "Video",
#     "postLikesCount": 9000,
#     "postCommentsCount": 196,
#     "postSharesCount": 25,
#     "postComments": []
# }
# {
#     "postType": "generic",
#     "postGroup": "",
#     "postAuthor": "Hi Peter here",
#     "postCaption": "Dưới đây là bình luận của các viên chức Sony khi hãng đang trong quá trình làm TASM2, được hé lộ trong các email bị leak của hãng vào năm 2014:",
#     "postMediaContent": "Image",
#     "postLikesCount": 299,
#     "postCommentsCount": 16,
#     "postSharesCount": 4,
#     "postComments": []
# }

# %%
with open('output.json', 'w', encoding='utf-8') as f:
    json.dump(output, f, ensure_ascii=False, indent=4)
